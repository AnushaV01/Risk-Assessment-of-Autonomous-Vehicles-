# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushaV01/Risk-Assessment-of-Autonomous-Vehicles-/blob/main/Risk_Profile_of_AV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Risk Profile**

# %%
import matplotlib.pyplot as plt

# Data for the risk profile
profits = [78.75, 157.5]
probabilities = [0.45, 0.55]

# Create the plot
plt.figure(figsize=(8, 6))
plt.stem(profits, probabilities, basefmt=" ", use_line_collection=True)

# Adding labels and title
plt.xlabel('Profit (Million USD)')
plt.ylabel('Probability')
plt.title('Risk Profile')

# Show the plot
plt.grid(True)
plt.show()
# Out:
# <ipython-input-1-f59aa622da14>:9: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(profits, probabilities, basefmt=" ", use_line_collection=True)
